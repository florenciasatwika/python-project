# %% [markdown]
# <a href="https://colab.research.google.com/github/florenciasatwika/python-project/blob/main/1_lab_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Test
#
# - Can you see this sentence?
# - Welcome to Google Colab!
# - This cell is for text.
#
# *   Test item 1
# *   Test item 2

# %%
# Here's for the code: Unless you add # mark at the beginning of a line, Jupyter Notebook understands the text here as code.
# For example,

print("See, this is how you print text using Python code.")
print(4+6)
# Out:
# See, this is how you print text using Python code.
# 10

# %% [markdown]
# Now, play with the command `print()` more. By modifying the above Python commands, print out your own name and short introduction!

# %%
name = "Florencia Satwika Genah"
age = 31
occupation = "Senior Statistician"
office = "BPS-Statistics Indonesia"

print("Hello my name is " + name +".")
print("I am " + str(age) + " years old.")
print("I work at "+ office + " as a " + occupation + ".")
# Out:
# Hello my name is Florencia Satwika Genah.
# I am 31 years old.
# I work at BPS-Statistics Indonesia as a Senior Statistician.
